# %% [markdown]
# # More Advanced Pandas
#
# In this notebook we look at further aspects of working with Pandas DataFrames and Series, including normalising data, aggregating data, and addressing the problem of missing values in a DataFrame.

# %% [markdown]
# Firstly, we will load a dataset of country-level statistics.

# %%
import pandas as pd

# %%
# read the dataset and set the index column
df = pd.read_csv("data/world_data.csv", index_col="Country")
# look at the first few rows
df.head()
# Out:
#                   Region  Population  Life Exp Landlocked    Language
# Country
# Argentina  South America       43.59     75.77         No     Spanish
# Australia        Oceania       23.99     82.09         No     English
# Brazil     South America      200.40     73.12         No  Portuguese
# Canada     North America       35.99     80.99         No     English
# Chad              Africa       11.63     49.81        Yes      Arabic

# %% [markdown]
# ## Frequency Tables
#
# When working with a Series with categorical values, frequency tables in Pandas provide a way of counting the frequency of different values in the Series. The function *value_counts()* returns a new Series containing counts of unique values. By default, these values are sorted.
#
# https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
#
# We could apply this to any of the categorical columns in our DataFrame.

# %%
df["Region"].value_counts()
# Out:
# Region
# Europe           6
# Africa           4
# North America    3
# South America    3
# Asia             3
# Oceania          2
# Name: count, dtype: int64

# %%
df["Language"].value_counts()
# Out:
# Language
# English       7
# Spanish       4
# Portuguese    2
# Arabic        2
# German        2
# Chinese       1
# Japanese      1
# French        1
# Korean        1
# Name: count, dtype: int64

# %%
df["Landlocked"].value_counts()
# Out:
# Landlocked
# No     17
# Yes     4
# Name: count, dtype: int64

# %% [markdown]
# We can also normalise the values, to give the relative frequencies of the unique values (i.e. the fraction of entries in the Series which have a given value):

# %%
df["Language"].value_counts(normalize=True)
# Out:
# Language
# English       0.333333
# Spanish       0.190476
# Portuguese    0.095238
# Arabic        0.095238
# German        0.095238
# Chinese       0.047619
# Japanese      0.047619
# French        0.047619
# Korean        0.047619
# Name: proportion, dtype: float64

# %%
df["Region"].value_counts(normalize=True)
# Out:
# Region
# Europe           0.285714
# Africa           0.190476
# North America    0.142857
# South America    0.142857
# Asia             0.142857
# Oceania          0.095238
# Name: proportion, dtype: float64

# %%
df["Landlocked"].value_counts(normalize=True)
# Out:
# Landlocked
# No     0.809524
# Yes    0.190476
# Name: proportion, dtype: float64

# %% [markdown]
# ## Aggregating Data
#
# We can use the *groupby()* function to group data based on the values in a categorical column:
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %%
# group the countries by their region value
groups1 = df.groupby("Region")

# %% [markdown]
# We can now apply a range of statistical operations on the groups:

# %%
# get the mean of the numeric columns, per group
groups1.mean(numeric_only=True)
# Out:
#                Population   Life Exp
# Region
# Africa          76.760000  56.680000
# Asia           511.656667  80.820000
# Europe          36.123333  81.191667
# North America  161.546667  78.183333
# Oceania         14.325000  81.380000
# South America   83.590000  75.293333

# %%
# get the total of the numeric columns, per group
groups1.sum(numeric_only=True)
# Out:
#                Population  Life Exp
# Region
# Africa             307.04    226.72
# Asia              1534.97    242.46
# Europe             216.74    487.15
# North America      484.64    234.55
# Oceania             28.65    162.76
# South America      250.77    225.88

# %%
# use an alternative categorical variable to aggregate the data
groups2 = df.groupby("Language")
groups2.mean(numeric_only=True)
# Out:
#              Population   Life Exp
# Language
# Arabic        51.000000  60.145000
# Chinese     1357.000000  74.870000
# English       91.777143  76.257143
# French        18.050000  55.130000
# German        44.790000  81.370000
# Japanese     126.260000  84.360000
# Korean        51.710000  83.230000
# Portuguese   105.345000  76.900000
# Spanish       56.270000  77.825000

# %%
# use an alternative categorical variable to aggregate the data
groups2 = df.groupby("Landlocked")
groups2.mean(numeric_only=True)
# Out:
#             Population   Life Exp
# Landlocked
# No          163.425294  77.358235
# Yes          11.145000  66.107500

# %% [markdown]
# ## Cross Tabulation
#
# *Cross tabulation* allows us to quantitatively analyse the relationship between multiple variables. In Pandas, this involves counting the frequency with which values from different columns in a DataFrame co-occur.
#
# https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html

# %% [markdown]
# In the simplest case, we can compare one column relative to another (our new index). For example, compare the Region and Landlocked columns, where Region will be the row index in the new DataFrame.

# %%
# compare a pair of categorical variables
pd.crosstab(df["Region"], df["Landlocked"])
# Out:
# Landlocked     No  Yes
# Region
# Africa          2    2
# Asia            3    0
# Europe          5    1
# North America   3    0
# Oceania         2    0
# South America   2    1

# %%
# compare a different pair of categorical variables
pd.crosstab(df["Language"], df["Landlocked"])
# Out:
# Landlocked  No  Yes
# Language
# Arabic       1    1
# Chinese      1    0
# English      7    0
# French       0    1
# German       1    1
# Japanese     1    0
# Korean       1    0
# Portuguese   2    0
# Spanish      3    1

# %%
# compare a different pair of categorical variables
pd.crosstab(df["Region"], df["Language"])
# Out:
# Language       Arabic  Chinese  English  French  German  Japanese  Korean  \
# Region
# Africa              2        0        1       1       0         0       0
# Asia                0        1        0       0       0         1       1
# Europe              0        0        2       0       2         0       0
# North America       0        0        2       0       0         0       0
# Oceania             0        0        2       0       0         0       0
# South America       0        0        0       0       0         0       0
#
# Language       Portuguese  Spanish
# Region
# Africa                  0        0
# Asia                    0        0
# Europe                  1        1
# North America           0        1
# Oceania                 0        0
# South America           1        2

# %% [markdown]
# ## Data Normalisation
#
# Data normalisation is a preprocessing step which is often applied to numeric columns to transform their scale or range.
#
# For instance, for country population data, we could normalise the values in this column in different ways.
#
# We could divided by the maximum value in the series:

# %%
df["Pop Norm"] = df["Population"] / df["Population"].max()
df.head(10)
# Out:
#                   Region  Population  Life Exp Landlocked    Language  \
# Country
# Argentina  South America       43.59     75.77         No     Spanish
# Australia        Oceania       23.99     82.09         No     English
# Brazil     South America      200.40     73.12         No  Portuguese
# Canada     North America       35.99     80.99         No     English
# Chad              Africa       11.63     49.81        Yes      Arabic
# China               Asia     1357.00     74.87         No     Chinese
# Egypt             Africa       90.37     70.48         No      Arabic
# Germany           Europe       81.46     80.24         No      German
# Ireland           Europe        4.64     80.15         No     English
# Japan               Asia      126.26     84.36         No    Japanese
#
#            Pop Norm
# Country
# Argentina  0.032122
# Australia  0.017679
# Brazil     0.147679
# Canada     0.026522
# Chad       0.008570
# China      1.000000
# Egypt      0.066595
# Germany    0.060029
# Ireland    0.003419
# Japan      0.093043

# %% [markdown]
# Alternatively, we could subtract the mean value from each value in the column. Note that this can give negative values:

# %%
df["Pop Norm"] = df["Population"] - df["Population"].mean()
df.head(10)
# Out:
#                   Region  Population  Life Exp Landlocked    Language  \
# Country
# Argentina  South America       43.59     75.77         No     Spanish
# Australia        Oceania       23.99     82.09         No     English
# Brazil     South America      200.40     73.12         No  Portuguese
# Canada     North America       35.99     80.99         No     English
# Chad              Africa       11.63     49.81        Yes      Arabic
# China               Asia     1357.00     74.87         No     Chinese
# Egypt             Africa       90.37     70.48         No      Arabic
# Germany           Europe       81.46     80.24         No      German
# Ireland           Europe        4.64     80.15         No     English
# Japan               Asia      126.26     84.36         No    Japanese
#
#               Pop Norm
# Country
# Argentina   -90.829524
# Australia  -110.429524
# Brazil       65.980476
# Canada      -98.429524
# Chad       -122.789524
# China      1222.580476
# Egypt       -44.049524
# Germany     -52.959524
# Ireland    -129.779524
# Japan        -8.159524

# %% [markdown]
# A particularly common form of normalisation is to compute a *Z-score*, which involves subtracting the mean value of a variable for each value and then dividing by its standard deviation:
#
# https://en.wikipedia.org/wiki/Standard_score

# %%
df["Pop Norm"] = (df["Population"] - df["Population"].mean())/df["Population"].std()
df.head(10)
# Out:
#                   Region  Population  Life Exp Landlocked    Language  \
# Country
# Argentina  South America       43.59     75.77         No     Spanish
# Australia        Oceania       23.99     82.09         No     English
# Brazil     South America      200.40     73.12         No  Portuguese
# Canada     North America       35.99     80.99         No     English
# Chad              Africa       11.63     49.81        Yes      Arabic
# China               Asia     1357.00     74.87         No     Chinese
# Egypt             Africa       90.37     70.48         No      Arabic
# Germany           Europe       81.46     80.24         No      German
# Ireland           Europe        4.64     80.15         No     English
# Japan               Asia      126.26     84.36         No    Japanese
#
#            Pop Norm
# Country
# Argentina -0.311463
# Australia -0.378674
# Brazil     0.226254
# Canada    -0.337524
# Chad      -0.421057
# China      4.192348
# Egypt     -0.151050
# Germany   -0.181603
# Ireland   -0.445027
# Japan     -0.027980

# %% [markdown]
# Another common normalisation method is *min-max normalisation*, which rescales the range of a feature's values to [0,1], based on its minimum and maximum values. We could apply this to the life expectancy values in our dataset as follows:

# %%
life_min = df["Life Exp"].min()
life_max = df["Life Exp"].max()
df["Life Exp Norm"] = (df["Life Exp"]-life_min)/(life_max-life_min)
df.head(10)
# Out:
#                   Region  Population  Life Exp Landlocked    Language  \
# Country
# Argentina  South America       43.59     75.77         No     Spanish
# Australia        Oceania       23.99     82.09         No     English
# Brazil     South America      200.40     73.12         No  Portuguese
# Canada     North America       35.99     80.99         No     English
# Chad              Africa       11.63     49.81        Yes      Arabic
# China               Asia     1357.00     74.87         No     Chinese
# Egypt             Africa       90.37     70.48         No      Arabic
# Germany           Europe       81.46     80.24         No      German
# Ireland           Europe        4.64     80.15         No     English
# Japan               Asia      126.26     84.36         No    Japanese
#
#            Pop Norm  Life Exp Norm
# Country
# Argentina -0.311463       0.751375
# Australia -0.378674       0.934298
# Brazil     0.226254       0.674674
# Canada    -0.337524       0.902460
# Chad      -0.421057       0.000000
# China      4.192348       0.725326
# Egypt     -0.151050       0.598263
# Germany   -0.181603       0.880753
# Ireland   -0.445027       0.878148
# Japan     -0.027980       1.000000

# %% [markdown]
# ## Handling Missing Values
#
# Many real datasets have missing values, either because they exist and were not collected or because the values never existed.
#
# In the example here, we consider a different dataset representing the passenger list from the Titanic.

# %%
# load the data and use the passenger Id as the row index for the DataFrame
dft = pd.read_csv("data/titanic.csv", index_col="PassengerId")
dft.head(20)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3                         Svensson, Mr. Johan Cervin
# 898               3                               Connolly, Miss. Kate
# 899               2                       Caldwell, Mr. Albert Francis
# 900               3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901               3                            Davies, Mr. John Samuel
# 902               3                                   Ilieff, Mr. Ylio
# 903               1                         Jones, Mr. Charles Cresson
# 904               1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 905               2                               Howard, Mr. Benjamin
# 906               1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 907               2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 908               2                                  Keane, Mr. Daniel
# 909               3                                  Assaf, Mr. Gerios
# 910               3                       Ilmakangas, Miss. Ida Livija
# 911               3              Assaf Khalil, Mrs. Mariana (Miriam")"
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 892            male  34.5      0      0            330911   7.8292   NaN
# 893          female  47.0      1      0            363272   7.0000   NaN
# 894            male  62.0      0      0            240276   9.6875   NaN
# 895            male  27.0      0      0            315154   8.6625   NaN
# 896          female  22.0      1      1           3101298  12.2875   NaN
# 897            male  14.0      0      0              7538   9.2250   NaN
# 898          female  30.0      0      0            330972   7.6292   NaN
# 899            male  26.0      1      1            248738  29.0000   NaN
# 900          female  18.0      0      0              2657   7.2292   NaN
# 901            male  21.0      2      0         A/4 48871  24.1500   NaN
# 902            male   NaN      0      0            349220   7.8958   NaN
# 903            male  46.0      0      0               694  26.0000   NaN
# 904          female  23.0      1      0             21228  82.2667   B45
# 905            male  63.0      1      0             24065  26.0000   NaN
# 906          female  47.0      1      0       W.E.P. 5734  61.1750   E31
# 907          female  24.0      1      0     SC/PARIS 2167  27.7208   NaN
# 908            male  35.0      0      0            233734  12.3500   NaN
# 909            male  21.0      0      0              2692   7.2250   NaN
# 910          female  27.0      1      0  STON/O2. 3101270   7.9250   NaN
# 911          female  45.0      0      0              2696   7.2250   NaN
#
#             Embarked
# PassengerId
# 892                Q
# 893                S
# 894                Q
# 895                S
# 896                S
# 897                S
# 898                Q
# 899                S
# 900                C
# 901                S
# 902                S
# 903                S
# 904                S
# 905                S
# 906                S
# 907                C
# 908                Q
# 909                C
# 910                S
# 911                C

# %%
dft.shape
# Out:
# (418, 10)

# %% [markdown]
# When we load the dataset *titanic.csv* dataset, we see that some columns have many missing values - i.e. they contain the null/empty value *NaN*.

# %%
# how many missing values per column?
dft.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# One option is to simply drop a feature with many missing values. So we could drop the "Age" column using the drop() function:

# %%
dft.drop(["Age"], axis=1)
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892              0      0              330911    7.8292   NaN        Q
# 893              1      0              363272    7.0000   NaN        S
# 894              0      0              240276    9.6875   NaN        Q
# 895              0      0              315154    8.6625   NaN        S
# 896              1      1             3101298   12.2875   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [418 rows x 9 columns]

# %% [markdown]
# However, if we expect age to play an important role, then we want to keep the column and estimate the missing values in some way. A simple approach is to fill in missing values using the mean value. We can do this using the *fillna()* function.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html

# %%
mean_age = dft["Age"].mean()
mean_age
# Out:
# np.float64(30.272590361445783)

# %%
# replace all NaN values in the Age column with the mean value
dft["Age"] = dft["Age"].fillna(mean_age)
dft.head(20)
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3                         Svensson, Mr. Johan Cervin
# 898               3                               Connolly, Miss. Kate
# 899               2                       Caldwell, Mr. Albert Francis
# 900               3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901               3                            Davies, Mr. John Samuel
# 902               3                                   Ilieff, Mr. Ylio
# 903               1                         Jones, Mr. Charles Cresson
# 904               1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 905               2                               Howard, Mr. Benjamin
# 906               1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 907               2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 908               2                                  Keane, Mr. Daniel
# 909               3                                  Assaf, Mr. Gerios
# 910               3                       Ilmakangas, Miss. Ida Livija
# 911               3              Assaf Khalil, Mrs. Mariana (Miriam")"
#
#                 Sex       Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 892            male  34.50000      0      0            330911   7.8292   NaN
# 893          female  47.00000      1      0            363272   7.0000   NaN
# 894            male  62.00000      0      0            240276   9.6875   NaN
# 895            male  27.00000      0      0            315154   8.6625   NaN
# 896          female  22.00000      1      1           3101298  12.2875   NaN
# 897            male  14.00000      0      0              7538   9.2250   NaN
# 898          female  30.00000      0      0            330972   7.6292   NaN
# 899            male  26.00000      1      1            248738  29.0000   NaN
# 900          female  18.00000      0      0              2657   7.2292   NaN
# 901            male  21.00000      2      0         A/4 48871  24.1500   NaN
# 902            male  30.27259      0      0            349220   7.8958   NaN
# 903            male  46.00000      0      0               694  26.0000   NaN
# 904          female  23.00000      1      0             21228  82.2667   B45
# 905            male  63.00000      1      0             24065  26.0000   NaN
# 906          female  47.00000      1      0       W.E.P. 5734  61.1750   E31
# 907          female  24.00000      1      0     SC/PARIS 2167  27.7208   NaN
# 908            male  35.00000      0      0            233734  12.3500   NaN
# 909            male  21.00000      0      0              2692   7.2250   NaN
# 910          female  27.00000      1      0  STON/O2. 3101270   7.9250   NaN
# 911          female  45.00000      0      0              2696   7.2250   NaN
#
#             Embarked
# PassengerId
# 892                Q
# 893                S
# 894                Q
# 895                S
# 896                S
# 897                S
# 898                Q
# 899                S
# 900                C
# 901                S
# 902                S
# 903                S
# 904                S
# 905                S
# 906                S
# 907                C
# 908                Q
# 909                C
# 910                S
# 911                C

# %% [markdown]
# Confirm that the "Age" column no longer has any missing values:

# %%
dft.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64
